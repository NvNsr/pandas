# %%
import pandas as pd

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
 'year': [2000, 2001, 2002, 2001, 2002, 2003],
 'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
frame=pd.DataFrame(data,index=[11,22,33,44,55,66])

# %%
frame
# Out:
#     pop   state  year
# 11  1.5    Ohio  2000
# 22  1.7    Ohio  2001
# 33  3.6    Ohio  2002
# 44  2.4  Nevada  2001
# 55  2.9  Nevada  2002
# 66  3.2  Nevada  2003

# %%
frame=pd.DataFrame(data,columns=["year","state","pop","extra"])

# %%
frame
# Out:
#    year   state  pop extra
# 0  2000    Ohio  1.5   NaN
# 1  2001    Ohio  1.7   NaN
# 2  2002    Ohio  3.6   NaN
# 3  2001  Nevada  2.4   NaN
# 4  2002  Nevada  2.9   NaN
# 5  2003  Nevada  3.2   NaN

# %%
frame=pd.DataFrame(data,columns=["year","state","pop","debt"],index=["one","two","three","four","five","six"])

# %%
frame
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
frame["state"]
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame.state
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame.loc["one"]
# Out:
# year     2000
# state    Ohio
# pop       1.5
# debt      NaN
# Name: one, dtype: object

# %%
val=pd.Series([-1.2,-2.3,-4.5],index=["two","three","five"])

# %%
val
# Out:
# two     -1.2
# three   -2.3
# five    -4.5
# dtype: float64

# %%
frame.debt=val

# %%
frame
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6  -2.3
# four   2001  Nevada  2.4   NaN
# five   2002  Nevada  2.9  -4.5
# six    2003  Nevada  3.2   NaN

# %%
pop = {'Nevada': {2001: 2.4, 2002: 2.9},'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %%
frame2=pd.DataFrame(pop)

# %%
frame2
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
frame2=pd.DataFrame(pop,index=[2001,2002,2003])
frame2
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2003     NaN   NaN

# %%
frame2.T
# Out:
#         2001  2002  2003
# Nevada   2.4   2.9   NaN
# Ohio     1.7   3.6   NaN

# %%
pdata = {'Ohio': frame2['Ohio'][:-1],'Nevada': frame2['Nevada'][:2]}

# %%
pdata
# Out:
# {'Nevada': 2001    2.4
#  2002    2.9
#  Name: Nevada, dtype: float64, 'Ohio': 2001    1.7
#  2002    3.6
#  Name: Ohio, dtype: float64}

# %%
pd.DataFrame(pdata)
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
frame2.index.name="year";frame2.columns.name="state"

# %%
frame2
# Out:
# state  Nevada  Ohio
# year
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2003      NaN   NaN

# %% [markdown]
# #  Essential Functionality

# %% [raw]
#  Essential Functionality on series

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])

# %%
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])

# %%
obj3.reindex(range(6))
# Out:
# 0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4    yellow
# 5       NaN
# dtype: object

# %%
 obj3.reindex(range(6), method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
 obj3.reindex(range(6), method='bfill')
# Out:
# 0      blue
# 1    purple
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object

# %% [raw]
# Essential Functionality on frame

# %%
import numpy as np

# %%
frame4 = pd.DataFrame(np.arange(9).reshape((3, 3)),index=['a', 'c', 'd'],columns=['Ohio', 'Texas', 'California'])

# %%
frame4
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame5 = frame4.reindex(['a', 'b', 'c', 'd'])
frame5
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
states = ["Texas", "Utah", "California"]

# %%
frame6=frame5.reindex(columns=states)
frame6
# Out:
#    Texas  Utah  California
# a    1.0   NaN         2.0
# b    NaN   NaN         NaN
# c    4.0   NaN         5.0
# d    7.0   NaN         8.0

# %%
frame6.reindex(index=["f","b","a","d","c","g"],columns=["texas","newyork","utah","bay"])
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
data=pd.DataFrame(np.arange(1,16).reshape((3,5)),columns=["a","b","c","d","e"])
data
# Out:
#     a   b   c   d   e
# 0   1   2   3   4   5
# 1   6   7   8   9  10
# 2  11  12  13  14  15

# %%
data=pd.DataFrame(np.arange(1,101).reshape((20,5)),columns=["a","b","c","d","e"],index=range(1,101,5))

# %%
data
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
data=pd.DataFrame(np.arange(1,101).reshape((20,5)),columns=list("abcde"),index=range(1,101,5))

# %%
data
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame.loc["a"]
# Out:
# Ohio          0
# Texas         1
# California    2
# Name: a, dtype: int32

# %%
frame.loc[::2]
# Out:
#    Ohio  Texas  California
# a     0      1           2
# d     6      7           8

# %%
frame.loc[::-1,::-1]
# Out:
#    California  Texas  Ohio
# d           8      7     6
# c           5      4     3
# a           2      1     0

# %%
frame.loc["a":"c"]
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5

# %%
frame2.iloc[0:3]
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0

# %%
frame2.loc["b"][[0]]=[4]

# %%
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame2.loc["b"],[0]
# Out:
# (Ohio          4.0
#  Texas         NaN
#  California    NaN
#  Name: b, dtype: float64, [0])

# %%
frame2.loc["b"]
# Out:
# Ohio          4.0
# Texas         NaN
# California    NaN
# Name: b, dtype: float64

# %% [markdown]
# # swaping

# %%
frame2.loc["b"][[2,0]]=frame2.loc["b"][[0,2]]

# %%
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         4.0
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %% [markdown]
# operation with nan gives nan in return

# %%
frame7=frame2.copy()

# %%
frame7["stud"]=[2,3,4,5]

# %%
frame7
# Out:
#    Ohio  Texas  California  stud
# a   0.0    1.0         2.0     2
# b   NaN    NaN         4.0     3
# c   3.0    4.0         5.0     4
# d   6.0    7.0         8.0     5

# %%
frame2+frame7
# Out:
#    California  Ohio  Texas  stud
# a         4.0   0.0    2.0   NaN
# b         8.0   NaN    NaN   NaN
# c        10.0   6.0    8.0   NaN
# d        16.0  12.0   14.0   NaN

# %%
frame7.loc[::-1] #for index
# Out:
#    Ohio  Texas  California  stud
# d   6.0    7.0         8.0     5
# c   3.0    4.0         5.0     4
# b   NaN    NaN         4.0     3
# a   0.0    1.0         2.0     2

# %%
frame7.loc[::-1,::-1] #for coloumn changing
# Out:
#    stud  California  Texas  Ohio
# d     5         8.0    7.0   6.0
# c     4         5.0    4.0   3.0
# b     3         4.0    NaN   NaN
# a     2         2.0    1.0   0.0

# %%
frame.loc["d"][0]= 6
frame7
# Out:
#    Ohio  Texas  California  stud
# a   0.0    1.0         2.0     2
# b   NaN    NaN         4.0     3
# c   3.0    4.0         5.0     4
# d   6.0    7.0         8.0     5

# %%
frame7.fillna(0) #only for runtime change
# Out:
#    Ohio  Texas  California  stud
# a   0.0    1.0         2.0     2
# b   0.0    0.0         4.0     3
# c   3.0    4.0         5.0     4
# d   6.0    7.0         8.0     5

# %%
frame7
# Out:
#    Ohio  Texas  California  stud
# a   0.0    1.0         2.0     2
# b   NaN    NaN         4.0     3
# c   3.0    4.0         5.0     4
# d   6.0    7.0         8.0     5

# %%
frame7.fillna(0,inplace=True) #change original data

# %%
frame7
# Out:
#    Ohio  Texas  California  stud
# a   0.0    1.0         2.0     2
# b   0.0    0.0         4.0     3
# c   3.0    4.0         5.0     4
# d   6.0    7.0         8.0     5

# %%
df=pd.read_csv("jTeOBO.csv")
df.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
df["Best of Quizzes"]
# Out:
# 0     8
# 1     5
# 2     5
# 3     7
# 4     7
# 5     9
# 6     6
# 7     9
# 8     9
# 9     8
# 10    8
# 11    8
# 12    7
# 13    8
# 14    7
# 15    0
# 16    5
# 17    8
# 18    5
# 19    9
# 20    7
# 21    9
# 22    7
# 23    5
# 24    5
# 25    9
# 26    6
# 27    8
# 28    6
# 29    7
# 30    8
# 31    7
# 32    2
# 33    4
# 34    9
# 35    8
# 36    9
# 37    9
# 38    6
# 39    4
# 40    9
# 41    7
# 42    6
# 43    9
# 44    7
# 45    9
# 46    8
# 47    9
# Name: Best of Quizzes, dtype: int64

# %%
a=df["result"]=["pass" if i > 7 else "Fail" for i in df["Best of Quizzes"]]

# %%
a
# Out:
# ['pass',
#  'Fail',
#  'Fail',
#  'Fail',
#  'Fail',
#  'pass',
#  'Fail',
#  'pass',
#  'pass',
#  'pass',
#  'pass',
#  'pass',
#  'Fail',
#  'pass',
#  'Fail',
#  'Fail',
#  'Fail',
#  'pass',
#  'Fail',
#  'pass',
#  'Fail',
#  'pass',
#  'Fail',
#  'Fail',
#  'Fail',
#  'pass',
#  'Fail',
#  'pass',
#  'Fail',
#  'Fail',
#  'pass',
#  'Fail',
#  'Fail',
#  'Fail',
#  'pass',
#  'pass',
#  'pass',
#  'pass',
#  'Fail',
#  'Fail',
#  'pass',
#  'Fail',
#  'Fail',
#  'pass',
#  'Fail',
#  'pass',
#  'pass',
#  'pass']

# %%
df[df["Best of Quizzes"]>7 ].count()
# Out:
# Student Code            23
# Degree                  23
# Student Name            23
# Mid                     23
# Quiz 1                  23
# Quiz 2                  23
# Best of Quizzes         23
# Assignment 1            22
# Assignment 2            16
# Best of Assignments     23
# Total Sessional (50)    23
# Final (50)              23
# Total (100)             23
# Grade                   23
# result                  23
# dtype: int64

# %%
b=df[(df["Best of Quizzes"]>7) & (df["Best of Assignments"]>7)]

# %%
b
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 27  022-14-110452  BS(CS)             Muhammad Osama Khan   27     8.0
# ...
